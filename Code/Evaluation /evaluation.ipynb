# %% [markdown]
# # Evaluation Script
#
# Notebook implementing evaluation metrics for Poems generated (Haiku) -
#
# - **Metric 1:** accesses the quality of text
#   - GRUEN: https://aclanthology.org/2020.findings-emnlp.9.pdf
#   - Github: https://github.com/WanzhengZhu/GRUEN
#
# - **Metric 2:** accesses the structure of text
#   - Mean Syllable count for each line (should be 5-7-5 for Haiku)

# %% [markdown]
# # Installs and Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Haiku-Generation
# Out:
# /content/drive/MyDrive/Haiku-Generation

# %%
cd GRUEN
# Out:
# /content/drive/MyDrive/Haiku-Generation/GRUEN

# %% [markdown]
# ### GRUEN installs

# %%
'''Need to run for 1st time setup'''
# !git clone https://github.com/WanzhengZhu/GRUEN.git
# cd GRUEN
# ! pip install -r requirements.txt
# !pip install --upgrade --no-cache-dir gdown
# !gdown --id 1S-l0L_YOzn5KhYHdB8iS37qKwuUhHP0G
# !unzip cola_model.zip
# Out:
# 'No need to run'

# %%
# %%capture
# !pip install transformers
# !pip install wmd
# !python -m spacy download en_core_web_md

import nltk
nltk.download('punkt')

from greun import *

import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### Syllables install

# %%
#for phonemizer
# %%capture
# !pip install phonemizer
# !sudo apt-get install festival

from phonemizer import phonemize
from phonemizer.separator import Separator

# %% [markdown]
# # Steps to run via terminal
#
# - Ensure all installs and setup have been made
# - Make sure you can access the GRUEN folder (the file imports greun.py file)
# - Pass the csv data path file into the command line
#   - The csv must have 3 columns namely ['sent_1', 'sent_2', 'sent_3'] that each has 1 line of the corresponding poem
#   - File running Example
#
# ```
# python evaluation.py '/content/drive/MyDrive/output.csv'
# ```
#
# - The file would print the mean, median and quantile of the scores achieved for each poem.

# %% [markdown]
# # Trial GRUEN (Github reference)
#
# Check if all installs work fine

# %%
candidates = [
    "All I need is faith to believe it",
    "I can feel my heart is beating faster",
    "'cause I'm so selfishly in love with you",
    "All I see is this big bright world",
    "I dont't think you are worth waiting with"
]

# %%
gruen_score = get_gruen(candidates)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/data/processors/glue.py:66: FutureWarning: This function will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/text-classification/run_glue.py
#   warnings.warn(DEPRECATION_WARNING.format("function"), FutureWarning)
# Evaluating: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]

# %%
print(
    sorted(list(zip(candidates, gruen_score)),
            key=lambda x: x[1],
            reverse=True))
# Out:
# [('All I see is this big bright world', 0.8570365309715271), ('All I need is faith to believe it', 0.8371034860610962), ('I can feel my heart is beating faster', 0.8120250403881073), ("I dont't think you are worth waiting with", 0.7390467375975708), ("'cause I'm so selfishly in love with you", 0.6723689770002683)]

# %% [markdown]
# # Req Func Syllable

# %%
def get_phonemes(line,char="|"):
  '''
  Get Phonemes 

  Arguments:
    Input:
      line (str) - text for calculating phn
  '''
  try:
    phn = phonemize(line, language='en-us', backend='festival', with_stress=False,
        separator=Separator(phone=None, word=' ', syllable=char), strip=True)
  except:
    # 1 syllable
    phn = ""
  return phn


def syllable_count(sen, char = "|"):
  '''
  Get Phonemes 

  Arguments:
    Input:
      sen (str) - phonemized structure split by char
  '''
  return sum([len(ph.split(char)) for ph in sen.split(" ")])


def get_data_syllables(data):
  '''
  Get syllable count for each line of poem

  Arguments: 
    data = 
  '''
  phenoemes_data = np.apply_along_axis(func1d=get_phonemes,arr=np.array(list(data)), axis=0)
  return [syllable_count(sen) for sen in phenoemes_data]

# %% [markdown]
# # Output Evaluation

# %% [markdown]
# ## HaikuRNN output

# %%
path = '/content/drive/MyDrive/CIS530-Project/Code/HaikuRNN_output/haiku_charrnn_final_output.csv'
data = pd.read_csv(path)
data.drop(data.columns[0],axis=1,inplace=True)
data.head()
# Out:
#                                               sent_1  \
# 0                                        flowers was
# 1                           a shadow and the colours
# 2  and the sound of the straight strange thinks t...
# 3       the sun is a silence the streets of a breeze
# 4     that standing at the sun and the can of strand
#
#                                               sent_2  \
# 0                   a straight of a child and shadow
# 1                     of a complex shaped to see the
# 2                             is a stream that i saw
# 3  in the windows on the stars and street and shaped
# 4                            and so the summer stars
#
#                                               sent_3
# 0                             on a cold street stars
# 1  stars and sheets and the streets are so sad an...
# 2             the world to see the stars of the wind
# 3   to start a barnes of street and the candle shade
# 4                          and stars are still there

# %%
data = pd.Series(list(data[['sent_1', 'sent_2', 'sent_3']].astype(str).values)).apply(lambda x: ' '.join(x)).to_list()

# %%
data[:5]
# Out:
# ['flowers was a straight of a child and shadow on a cold street stars',
#  'a shadow and the colours of a complex shaped to see the stars and sheets and the streets are so sad and stared',
#  'and the sound of the straight strange thinks that this is a stream that i saw the world to see the stars of the wind',
#  'the sun is a silence the streets of a breeze in the windows on the stars and street and shaped to start a barnes of street and the candle shade',
#  'that standing at the sun and the can of strand and so the summer stars and stars are still there']

# %%
'''error in running more than x number of data points'''
# gruen_score = get_gruen(data)

# %%
pd.DataFrame(sorted(list(zip(data, gruen_score)),
        key=lambda x: x[1],
        reverse=True),columns=['haiku','gruen_score']).to_csv('/content/drive/MyDrive/CIS530-Project/Code/HaikuRNN_output/haiku_charrnn_gruen_score.csv',index=False)

# %%
# pd.Series(gruen_score).describe()

# %%
for i in tqdm([data.columns[2]]):
  data[str(i)+"_syllable"] = get_data_syllables(data[i])
  
data[[col for col in data.columns if 'syllable' in col]].describe()
# Out:
#        sent_1_syllable  sent_2_syllable  sent_3_syllable
# count      1458.000000      1458.000000      1458.000000
# mean          7.586420         8.715364         8.039095
# std           3.964462         3.161504         4.051045
# min           2.000000         2.000000         1.000000
# 25%           5.000000         7.000000         5.000000
# 50%           5.000000         7.000000         6.000000
# 75%          10.000000        10.000000        11.000000
# max          35.000000        26.000000        31.000000

# %% [markdown]
# ## Spacy Output

# %%
path = '/content/drive/MyDrive/CIS530-Project/Code/Spacy_output/haiku_spacy_output_.csv'
data = pd.read_csv(path)
data.drop(data.columns[0],axis=1,inplace=True)
data.head()
# Out:
#                    sent_1                              sent_2  \
# 0        motherlode copy                into river below dam
# 1  wind's cold frostbite            nostalgia sinks in again
# 2    of the dawn heralds       moonlight is melting fleeting
# 3   now clear sky purple              happily alive and well
# 4   flowers in the field    retail stores furlough thousands
#
#                   sent_3
# 0     around til i crash
# 1       ears are icicles
# 2         now i am awake
# 3     bare and blackened
# 4   sign from the cosmos

# %%
data = pd.Series(list(data[['sent_1', 'sent_2', 'sent_3']].astype(str).values)).apply(lambda x: ' '.join(x)).to_list()

# %% [markdown]
# #### GRUEN

# %%
gruen_score = []
index = []
for i in tqdm(range(0,len(data),10)):
  try:
    gruen_score.extend(get_gruen(data[i:i+10]))
    index.extend(list(range(i,i+10)))
  except:
    pass

# %%
pd.DataFrame(pd.Series(gruen_score).describe(),columns=['gruen_score']).reset_index()
# Out:
#    index  gruen_score
# 0  count  1500.000000
# 1   mean     0.292812
# 2    std     0.131685
# 3    min     0.089615
# 4    25%     0.190310
# 5    50%     0.260279
# 6    75%     0.375368
# 7    max     0.793858

# %%
data = list(np.array(data)[list(set(index))])
pd.DataFrame(sorted(list(zip(data, gruen_score)),
        key=lambda x: x[1],
        reverse=True),columns=['haiku','gruen_score']).to_csv('/content/drive/MyDrive/CIS530-Project/Code/Spacy_output/haiku_spacy_gruen_score.csv',index=False)

# %% [markdown]
# #### Phenomes

# %%
haiku = pd.read_csv('/content/drive/MyDrive/CIS530-Project/Code/Spacy_output/haiku_spacy_gruen_score.csv')
haiku.head()
# Out:
#                                                haiku  gruen_score
# 0  slow steady breathing   in universal chaos   b...     0.793858
# 1  behind a mountain   concentric ripples shimmer...     0.779875
# 2  for a better home   tomorrow i will forget   e...     0.768513
# 3  conversations go   boundless possibilities   w...     0.739246
# 4  right before our eyes   black cumulonimbus clo...     0.720661

# %%
data['haiku'] = pd.Series(list(data[['sent_1', 'sent_2', 'sent_3']].astype(str).values)).apply(lambda x: ' '.join(x))
data = data.merge(haiku,on='haiku')

# %%
for i in tqdm(data.columns[:3]):
  data[str(i)+"_syllable"] = get_data_syllables(data[i])
# Out:
# 100%|██████████| 3/3 [00:44<00:00, 14.74s/it]

# %%
data[[col for col in data.columns if 'syllable' in col]].describe()
# Out:
#        sent_1_syllable  sent_2_syllable  sent_3_syllable
# count      1500.000000      1500.000000      1500.000000
# mean          4.914667         6.781333         4.920667
# std           0.420519         0.534517         0.387909
# min           3.000000         4.000000         3.000000
# 25%           5.000000         7.000000         5.000000
# 50%           5.000000         7.000000         5.000000
# 75%           5.000000         7.000000         5.000000
# max           7.000000         8.000000         8.000000

# %%
data.head()
# Out:
#                    sent_1                              sent_2  \
# 0        motherlode copy                into river below dam
# 1  wind's cold frostbite            nostalgia sinks in again
# 2    of the dawn heralds       moonlight is melting fleeting
# 3   now clear sky purple              happily alive and well
# 4   flowers in the field    retail stores furlough thousands
#
#                   sent_3                                              haiku  \
# 0     around til i crash  motherlode copy   into river below dam   aroun...
# 1       ears are icicles  wind's cold frostbite   nostalgia sinks in aga...
# 2         now i am awake  of the dawn heralds   moonlight is melting fle...
# 3     bare and blackened  now clear sky purple   happily alive and well ...
# 4   sign from the cosmos  flowers in the field   retail stores furlough ...
#
#    gruen_score  sent_1_syllable  sent_2_syllable  sent_3_syllable
# 0     0.251227                5                7                5
# 1     0.458207                4                7                5
# 2     0.429450                5                7                5
# 3     0.212137                5                7                4
# 4     0.246135                5                7                5

# %% [markdown]
# # Preprocessed Clean Data GRUEN

# %%
import os
main_path = '/content/drive/MyDrive/CIS530-Project/Data/Cleanup/csv_data/Final range/'
path = os.listdir(main_path)

data = pd.concat([pd.read_csv(os.path.join(main_path,i)) for i in path])
print(data.shape)

# other data
path = '/content/drive/MyDrive/CIS530-Project/Data/Cleanup/cleaned-data_firstrange.csv'
df = pd.read_csv(path)
df.drop(df.columns[0],axis=1,inplace=True)
data.columns  = df.columns
data = pd.concat([data,df])
print(data.shape)

path = '/content/drive/MyDrive/CIS530-Project/Data/Cleanup/cleaned-data_1.csv'
df = pd.read_csv(path)
df.drop(df.columns[0],axis=1,inplace=True)
df.columns = data.columns 
data = pd.concat([data,df])
print(data.shape)

data.head()
# Out:
# (40668, 11)
# (88157, 11)
# (99387, 11)
#                   sent_1                        sent_2  \
# 0   Damn, I really miss.         Us in our early days.
# 1     I've never wanted.        To go to Utah more in.
# 2   ALL people have the.         Capability to change.
# 3  Southern comfort and.      Tea with a bit of honey.
# 4   We are both courses.  But is structured as a pimp.
#
#                        sent_3  source          topic  sent_1_syllable  \
# 0           In our best days.  twaiku      best days              5.0
# 1             My entire life.  twaiku   never wanted              5.0
# 2  They just choose not, too.  twaiku  capability to              5.0
# 3          And a dash of ice.  twaiku        and tea              5.0
# 4          Now Newt inquired.  twaiku             is              5.0
#
#    sent_2_syllable  sent_3_syllable            sent_1_phoneme  \
# 0              7.0              5.0      daem ay rih|liy mihs
# 1              7.0              5.0     ayv neh|ver waan|taxd
# 2              7.0              5.0   aol piy|paxl hhaev dhax
# 3              7.0              5.0  sah|dhern kahm|fert aend
# 4              7.0              5.0   wiy aar bowth kaor|saxz
#
#                        sent_2_phoneme              sent_3_phoneme
# 0           ahs ihn aw|er er|liy deyz        ihn aw|er behst deyz
# 1        tax gow tax yuw|tao maor ihn         may axn|tay|er layf
# 2     key|pax|bih|lax|tiy tax cheynjh  dhey jhahst chuwz naat tuw
# 3      tiy wihdh ax biht ahv hhah|niy       aend ax daesh ahv ays
# 4  baht ihz strahk|cherd aez ax pihmp       naw nuwt axn|kway|erd

# %%
# data.to_csv('/content/drive/MyDrive/CIS530-Project/Data/preprocessed_cleaned_data_99k.csv',index=False,header=True)

# %%
data['poem'] = pd.Series(list(data[['sent_1', 'sent_2', 'sent_3']].astype(str).values)).apply(lambda x: ' '.join(x))

# %%
gruen_score = get_gruen(list(data['poem']))
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|██████████| 99387/99387 [8:12:27<00:00,  3.36it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/data/processors/glue.py:66: FutureWarning: This function will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/text-classification/run_glue.py
#   warnings.warn(DEPRECATION_WARNING.format("function"), FutureWarning)
# Evaluating:  21%|██        | 62066/294381 [8:00:43<29:59:22,  2.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-1dcb50869422> in <module>
# ----> 1 gruen_score = get_gruen(list(data['poem']))
#
# /content/drive/MyDrive/Haiku-Generation/GRUEN/greun.py in get_gruen(candidates)
#     283 def get_gruen(candidates):
#     284     processed_candidates = preprocess_candidates(candidates)
# --> 285     grammaticality_score = get_grammaticality_score(processed_candidates)
#     286     redundancy_score = get_redundancy_score(processed_candidates)
#     287     focus_score = get_focus_score(processed_candidates)
#
# /content/drive/MyDrive/Haiku-Generation/GRUEN/greun.py in get_grammaticality_score(processed_candidates)
#     187 def get_grammaticality_score(processed_candidates):
#     188     lm_score = get_lm_score(processed_candidates)
# --> 189     cola_score = get_cola_score(processed_candidates)
#     190     grammaticality_score = [
#     191         1.0 * math.exp(-0.5 * x) + 1.0 * y
#
# /content/drive/MyDrive/Haiku-Generation/GRUEN/greun.py in get_cola_score(sentences)
#     179     candidates = [y for x in sentences for y in x]
#     180     sent_length = [len(x) for x in sentences]
# --> 181     cola_score = evaluate_cola(model, candidates, tokenizer, model_name)
#     182     cola_score = convert_sentence_score_to_paragraph_score(
#     183         cola_score, sent_length)
#
# /content/drive/MyDrive/Haiku-Generation/GRUEN/greun.py in evaluate_cola(model, candidates, tokenizer, model_name)
#     152                         'bert', 'xlnet'
#     153                     ] else None  # XLM, DistilBERT and RoBERTa don't use segment_ids
# --> 154                 outputs = model(**inputs)
#     155                 tmp_eval_loss, logits = outputs[:2]
#     156
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1559             output_attentions=output_attentions,
#    1560             output_hidden_states=output_hidden_states,
# -> 1561             return_dict=return_dict,
#    1562         )
#    1563
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1022             output_attentions=output_attentions,
#    1023             output_hidden_states=output_hidden_states,
# -> 1024             return_dict=return_dict,
#    1025         )
#    1026         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     608                     encoder_attention_mask,
#     609                     past_key_value,
# --> 610                     output_attentions,
#     611                 )
#     612
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     530
#     531         layer_output = apply_chunking_to_forward(
# --> 532             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     533         )
#     534         outputs = (layer_output,) + outputs
#
# /usr/local/lib/python3.7/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     244         return torch.cat(output_chunks, dim=chunk_dim)
#     245
# --> 246     return forward_fn(*input_tensors)
#     247
#     248
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in feed_forward_chunk(self, attention_output)
#     542     def feed_forward_chunk(self, attention_output):
#     543         intermediate_output = self.intermediate(attention_output)
# --> 544         layer_output = self.output(intermediate_output, attention_output)
#     545         return layer_output
#     546
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     454
#     455     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 456         hidden_states = self.dense(hidden_states)
#     457         hidden_states = self.dropout(hidden_states)
#     458         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
import pickle
pickle.dump(gruen_score, open('wb', '/content/drive/MyDrive/CIS530-Project/Data/pickle_gruen.pkl'))

# %%
data['gruen_score'] = gruen_score
data.to_csv('/content/drive/MyDrive/CIS530-Project/Data/data_99k_gruen.csv',index=False,header=True)
